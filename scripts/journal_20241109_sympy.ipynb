# %%
import sympy as sp
from sympy.abc import alpha

# %%
sp.init_printing(use_latex=True)

# %%
x = sp.Symbol('x', real=True)

# %%
1/(sp.sqrt(1 - x**2)).subs({sp.sqrt(1-x**2): sp.sqrt((1-x))*sp.sqrt((1+x))})
# Out:
#          1
# ───────────────────
#   _______   _______
# ╲╱ 1 - x ⋅╲╱ x + 1

# %%
((sp.sqrt((1-x))*sp.sqrt((1+x)))**2).simplify()
# Out:
#      2
# 1 - x
